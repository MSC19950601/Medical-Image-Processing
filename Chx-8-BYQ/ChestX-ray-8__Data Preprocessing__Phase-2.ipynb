# %% [markdown]
# # ChestX-ray-8__Data Preprocessing__Phase-2

# %% [markdown]
# ### 1. import modules

# %%
import os
import numpy as np
from PIL import Image
import pandas as pd
import re

# %% [markdown]
# ### 2. locate the file

# %%
images_path = "F:/Data/Chest_Xray_Dataset/CXR-8-full-data/images"

# %% [markdown]
# ### 4. Now we gonna convert the csv file into a dataframe/np array

# %%
labels_path = "F:/Data/Chest_Xray_Dataset/CXR-8-full-data/Data_Entry_2017.csv"

# %%
df = pd.read_csv(labels_path)

# %% [markdown]
# #### below is the dataframe we need:

# %%
labels = df[['Image Index', 'Finding Labels']]

# %% [markdown]
# ### 5. Define the function to process the finding labels

# %%
existing_annotations = ['Atelectasis','Cardiomegaly','Effusion','Infiltration','Mass','Nodule','Pneumonia','Pneumothorax']
existing_annotations = np.asarray(existing_annotations)
len(existing_annotations)
# Out:
# 8

# %%
def process_findings(findings, annotations):
    """
    Parameters: findings as string, annotations as np array
    
    Output: onehot as np array
    
    """
    onehot = np.zeros(len(annotations))
    i = 0
    for disease in annotations:
        if bool(re.search(disease, findings)):
            onehot[i] = 1
        i = i + 1
    return onehot

# %% [markdown]
# ### 6. Upgrade the origin function into: get_images_and_labels

# %%
image_paths = [os.path.join(images_path, f) for f in os.listdir(images_path)]

# %%
def get_images_pro(paths, labels, begin_id, error_count_in, batch_size = 30):
    """
    Parameters:
        1. paths as list: a list which saves all the paths of pictures in "images" folder
        2. (two-column) labels as dataframe: the labels for the images
        3. begin-id as integer: the index of the first image in this batch (the batch to be processed)
        4. error_count_in: the number of images with wrong shape in all the batches before
        5. batch_size as integer: 30 by default
    
    Outputs:
        1. image_list as list: containing the arrays of shape (1024, 1024)
        2. label_list as list: containing the onehot np arrays of shape (, len(annotations))
        3. end_index as integer: the index for the last image in the batch just processed, to be passed into next iteration
        4. error_count: the number of images with wrong shape in all the batches processed, to be passed into next iteration
    
    """
    # Append all the absolute image paths in a list image_paths
    image_paths = paths
    # images will contains face images
    image_list = []
    label_list = []
    
    print("The total number of images is " + str(len(image_paths)))
    count = begin_id
    ceiling = begin_id + batch_size - 1
    error_count = error_count_in
    
    while True:
        # Read the image and convert to grayscale
        image_path = image_paths[count]
        image_pil = Image.open(image_path)
        # Convert the image format into numpy array
        image = np.array(image_pil, dtype = 'float')
        
        if image.shape == (1024, 1024):
            image_list.append(image)
            index = image_path.split("\\")[-1]
            findings = labels.loc[(df['Image Index']==index)].iloc[0][1]    
            label_list.append(process_findings(findings, existing_annotations))    
        else:
            ceiling = ceiling + 1
            error_count = error_count + 1
            
        count = count + 1
        
        if count % 50 == 0:
            print("Preprocessing images: " + str(count) + " /" + str(len(image_paths)))
        if count > ceiling:
            break
            
    end_index = ceiling
    print("Up to now " + str(count) + " images processed： " + str(error_count) + " pictures are not well shaped.")

             
    # return the images list and labels list
    return image_list, label_list, end_index, error_count

# %%
image_list, label_list, end_index, error_count = get_images_pro(image_paths, labels, 0, 0, 40)
# Out:
# The total number of images is 112120
# Up to now 41 images processed： 1 pictures are not well shaped.

# %%
end_index
# Out:
# 40

# %%
label_array = np.asarray(label_list)

# %%
image_array = np.asarray(image_list)

# %%
# np.save("F:/Data/Chest_Xray_Dataset/CXR-8-full-data/processed/label_array", label_array)

# %% [markdown]
# ### 7. The loop

# %% [markdown]
# Demonstration:

# %%
batch_id = 0
begin_id = 0
error_count_in = 0

while batch_id < 100:
    
    image_list, label_list, end_index, error_count = get_images_pro(image_paths, labels, begin_id, error_count_in, 128)
    error_count_in = error_count
    begin_id = end_index + 1
    
    label_array = np.asarray(label_list)
    image_array = np.asarray(image_list)
    np.save("F:/Data/Chest_Xray_Dataset/CXR-8-full-data/processed/label_array_batch_" + str(batch_id), label_array)
    np.save("F:/Data/Chest_Xray_Dataset/CXR-8-full-data/processed/image_array_batch_" + str(batch_id), image_array)
    print("No. of batches saved: " + str(batch_id + 1))

    batch_id = batch_id + 1
# Out:
# The total number of images is 112120
# Preprocessing images: 50 /112120
# Preprocessing images: 100 /112120
# Up to now 129 images processed： 1 pictures are not well shaped.
# No. of batches saved: 1
# The total number of images is 112120
# Preprocessing images: 150 /112120
# Preprocessing images: 200 /112120
# Preprocessing images: 250 /112120
# Up to now 257 images processed： 1 pictures are not well shaped.
# No. of batches saved: 2
# The total number of images is 112120
# Preprocessing images: 300 /112120
# Preprocessing images: 350 /112120
# Up to now 392 images processed： 8 pictures are not well shaped.
# No. of batches saved: 3
# The total number of images is 112120
# Preprocessing images: 400 /112120
# Preprocessing images: 450 /112120
# Preprocessing images: 500 /112120
# Up to now 523 images processed： 11 pictures are not well shaped.
# No. of batches saved: 4
# The total number of images is 112120
# Preprocessing images: 550 /112120
# Preprocessing images: 600 /112120
# Preprocessing images: 650 /112120
# Up to now 656 images processed： 16 pictures are not well shaped.
# No. of batches saved: 5
# The total number of images is 112120
# Preprocessing images: 700 /112120
# Preprocessing images: 750 /112120
# Up to now 784 images processed： 16 pictures are not well shaped.
# No. of batches saved: 6
# The total number of images is 112120
# Preprocessing images: 800 /112120
# Preprocessing images: 850 /112120
# Preprocessing images: 900 /112120
# Up to now 917 images processed： 21 pictures are not well shaped.
# No. of batches saved: 7
# The total number of images is 112120
# Preprocessing images: 950 /112120
# Preprocessing images: 1000 /112120
# Up to now 1045 images processed： 21 pictures are not well shaped.
# No. of batches saved: 8
# The total number of images is 112120
# Preprocessing images: 1050 /112120
# Preprocessing images: 1100 /112120
# Preprocessing images: 1150 /112120
# Up to now 1175 images processed： 23 pictures are not well shaped.
# No. of batches saved: 9
# The total number of images is 112120
# Preprocessing images: 1200 /112120
# Preprocessing images: 1250 /112120
# Preprocessing images: 1300 /112120
# Up to now 1307 images processed： 27 pictures are not well shaped.
# No. of batches saved: 10
# The total number of images is 112120
# Preprocessing images: 1350 /112120
# Preprocessing images: 1400 /112120
# Up to now 1437 images processed： 29 pictures are not well shaped.
# No. of batches saved: 11
# The total number of images is 112120
# Preprocessing images: 1450 /112120
# Preprocessing images: 1500 /112120
# Preprocessing images: 1550 /112120
# Up to now 1566 images processed： 30 pictures are not well shaped.
# No. of batches saved: 12
# The total number of images is 112120
# Preprocessing images: 1600 /112120
# Preprocessing images: 1650 /112120
# Up to now 1695 images processed： 31 pictures are not well shaped.
# No. of batches saved: 13
# The total number of images is 112120
# Preprocessing images: 1700 /112120
# Preprocessing images: 1750 /112120
# Preprocessing images: 1800 /112120
# Up to now 1823 images processed： 31 pictures are not well shaped.
# No. of batches saved: 14
# The total number of images is 112120
# Preprocessing images: 1850 /112120
# Preprocessing images: 1900 /112120
# Preprocessing images: 1950 /112120
# Up to now 1952 images processed： 32 pictures are not well shaped.
# No. of batches saved: 15
# The total number of images is 112120
# Preprocessing images: 2000 /112120
# Preprocessing images: 2050 /112120
# Up to now 2081 images processed： 33 pictures are not well shaped.
# No. of batches saved: 16
# The total number of images is 112120
# Preprocessing images: 2100 /112120
# Preprocessing images: 2150 /112120
# Preprocessing images: 2200 /112120
# Up to now 2210 images processed： 34 pictures are not well shaped.
# No. of batches saved: 17
# The total number of images is 112120
# Preprocessing images: 2250 /112120
# Preprocessing images: 2300 /112120
# Up to now 2339 images processed： 35 pictures are not well shaped.
# No. of batches saved: 18
# The total number of images is 112120
# Preprocessing images: 2350 /112120
# Preprocessing images: 2400 /112120
# Preprocessing images: 2450 /112120
# Up to now 2467 images processed： 35 pictures are not well shaped.
# No. of batches saved: 19
# The total number of images is 112120
# Preprocessing images: 2500 /112120
# Preprocessing images: 2550 /112120
# Up to now 2596 images processed： 36 pictures are not well shaped.
# No. of batches saved: 20
# The total number of images is 112120
# Preprocessing images: 2600 /112120
# Preprocessing images: 2650 /112120
# Preprocessing images: 2700 /112120
# Up to now 2724 images processed： 36 pictures are not well shaped.
# No. of batches saved: 21
# The total number of images is 112120
# Preprocessing images: 2750 /112120
# Preprocessing images: 2800 /112120
# Preprocessing images: 2850 /112120
# Up to now 2853 images processed： 37 pictures are not well shaped.
# No. of batches saved: 22
# The total number of images is 112120
# Preprocessing images: 2900 /112120
# Preprocessing images: 2950 /112120
# Up to now 2983 images processed： 39 pictures are not well shaped.
# No. of batches saved: 23
# The total number of images is 112120
# Preprocessing images: 3000 /112120
# Preprocessing images: 3050 /112120
# Preprocessing images: 3100 /112120
# Up to now 3112 images processed： 40 pictures are not well shaped.
# No. of batches saved: 24
# The total number of images is 112120
# Preprocessing images: 3150 /112120
# Preprocessing images: 3200 /112120
# Up to now 3243 images processed： 43 pictures are not well shaped.
# No. of batches saved: 25
# The total number of images is 112120
# Preprocessing images: 3250 /112120
# Preprocessing images: 3300 /112120
# Preprocessing images: 3350 /112120
# Up to now 3372 images processed： 44 pictures are not well shaped.
# No. of batches saved: 26
# The total number of images is 112120
# Preprocessing images: 3400 /112120
# Preprocessing images: 3450 /112120
# Preprocessing images: 3500 /112120
# Up to now 3504 images processed： 48 pictures are not well shaped.
# No. of batches saved: 27
# The total number of images is 112120
# Preprocessing images: 3550 /112120
# Preprocessing images: 3600 /112120
# Up to now 3636 images processed： 52 pictures are not well shaped.
# No. of batches saved: 28
# The total number of images is 112120
# Preprocessing images: 3650 /112120
# Preprocessing images: 3700 /112120
# Preprocessing images: 3750 /112120
# Up to now 3764 images processed： 52 pictures are not well shaped.
# No. of batches saved: 29
# The total number of images is 112120
# Preprocessing images: 3800 /112120
# Preprocessing images: 3850 /112120
# Up to now 3895 images processed： 55 pictures are not well shaped.
# No. of batches saved: 30
# The total number of images is 112120
# Preprocessing images: 3900 /112120
# Preprocessing images: 3950 /112120
# Preprocessing images: 4000 /112120
# Up to now 4023 images processed： 55 pictures are not well shaped.
# No. of batches saved: 31
# The total number of images is 112120
# Preprocessing images: 4050 /112120
# Preprocessing images: 4100 /112120
# Preprocessing images: 4150 /112120
# Up to now 4152 images processed： 56 pictures are not well shaped.
# No. of batches saved: 32
# The total number of images is 112120
# Preprocessing images: 4200 /112120
# Preprocessing images: 4250 /112120
# Up to now 4281 images processed： 57 pictures are not well shaped.
# No. of batches saved: 33
# The total number of images is 112120
# Preprocessing images: 4300 /112120
# Preprocessing images: 4350 /112120
# Preprocessing images: 4400 /112120
# Up to now 4409 images processed： 57 pictures are not well shaped.
# No. of batches saved: 34
# The total number of images is 112120
# Preprocessing images: 4450 /112120
# Preprocessing images: 4500 /112120
# Up to now 4539 images processed： 59 pictures are not well shaped.
# No. of batches saved: 35
# The total number of images is 112120
# Preprocessing images: 4550 /112120
# Preprocessing images: 4600 /112120
# Preprocessing images: 4650 /112120
# Up to now 4669 images processed： 61 pictures are not well shaped.
# No. of batches saved: 36
# The total number of images is 112120
# Preprocessing images: 4700 /112120
# Preprocessing images: 4750 /112120
# Preprocessing images: 4800 /112120
# Up to now 4803 images processed： 67 pictures are not well shaped.
# No. of batches saved: 37
# The total number of images is 112120
# Preprocessing images: 4850 /112120
# Preprocessing images: 4900 /112120
# Up to now 4935 images processed： 71 pictures are not well shaped.
# No. of batches saved: 38
# The total number of images is 112120
# Preprocessing images: 4950 /112120
# Preprocessing images: 5000 /112120
# Preprocessing images: 5050 /112120
# Up to now 5063 images processed： 71 pictures are not well shaped.
# No. of batches saved: 39
# The total number of images is 112120
# Preprocessing images: 5100 /112120
# Preprocessing images: 5150 /112120
# Up to now 5192 images processed： 72 pictures are not well shaped.
# No. of batches saved: 40
# The total number of images is 112120
# Preprocessing images: 5200 /112120
# Preprocessing images: 5250 /112120
# Preprocessing images: 5300 /112120
# Up to now 5322 images processed： 74 pictures are not well shaped.
# No. of batches saved: 41
# The total number of images is 112120
# Preprocessing images: 5350 /112120
# Preprocessing images: 5400 /112120
# Preprocessing images: 5450 /112120
# Up to now 5453 images processed： 77 pictures are not well shaped.
# No. of batches saved: 42
# The total number of images is 112120
# Preprocessing images: 5500 /112120
# Preprocessing images: 5550 /112120
# Up to now 5581 images processed： 77 pictures are not well shaped.
# No. of batches saved: 43
# The total number of images is 112120
# Preprocessing images: 5600 /112120
# Preprocessing images: 5650 /112120
# Preprocessing images: 5700 /112120
# Up to now 5710 images processed： 78 pictures are not well shaped.
# No. of batches saved: 44
# The total number of images is 112120
# Preprocessing images: 5750 /112120
# Preprocessing images: 5800 /112120
# Up to now 5841 images processed： 81 pictures are not well shaped.
# No. of batches saved: 45
# The total number of images is 112120
# Preprocessing images: 5850 /112120
# Preprocessing images: 5900 /112120
# Preprocessing images: 5950 /112120
# Up to now 5970 images processed： 82 pictures are not well shaped.
# No. of batches saved: 46
# The total number of images is 112120
# Preprocessing images: 6000 /112120
# Preprocessing images: 6050 /112120
# Preprocessing images: 6100 /112120
# Up to now 6100 images processed： 84 pictures are not well shaped.
# No. of batches saved: 47
# The total number of images is 112120
# Preprocessing images: 6150 /112120
# Preprocessing images: 6200 /112120
# Up to now 6229 images processed： 85 pictures are not well shaped.
# No. of batches saved: 48
# The total number of images is 112120
# Preprocessing images: 6250 /112120
# Preprocessing images: 6300 /112120
# Preprocessing images: 6350 /112120
# Up to now 6357 images processed： 85 pictures are not well shaped.
# No. of batches saved: 49
# The total number of images is 112120
# Preprocessing images: 6400 /112120
# Preprocessing images: 6450 /112120
# Up to now 6486 images processed： 86 pictures are not well shaped.
# No. of batches saved: 50
# The total number of images is 112120
# Preprocessing images: 6500 /112120
# Preprocessing images: 6550 /112120
# Preprocessing images: 6600 /112120
# Up to now 6616 images processed： 88 pictures are not well shaped.
# No. of batches saved: 51
# The total number of images is 112120
# Preprocessing images: 6650 /112120
# Preprocessing images: 6700 /112120
# Up to now 6744 images processed： 88 pictures are not well shaped.
# No. of batches saved: 52
# The total number of images is 112120
# Preprocessing images: 6750 /112120
# Preprocessing images: 6800 /112120
# Preprocessing images: 6850 /112120
# Up to now 6872 images processed： 88 pictures are not well shaped.
# No. of batches saved: 53
# The total number of images is 112120
# Preprocessing images: 6900 /112120
# Preprocessing images: 6950 /112120
# Preprocessing images: 7000 /112120
# Up to now 7000 images processed： 88 pictures are not well shaped.
# No. of batches saved: 54
# The total number of images is 112120
# Preprocessing images: 7050 /112120
# Preprocessing images: 7100 /112120
# Up to now 7129 images processed： 89 pictures are not well shaped.
# No. of batches saved: 55
# The total number of images is 112120
# Preprocessing images: 7150 /112120
# Preprocessing images: 7200 /112120
# Preprocessing images: 7250 /112120
# Up to now 7257 images processed： 89 pictures are not well shaped.
# No. of batches saved: 56
# The total number of images is 112120
# Preprocessing images: 7300 /112120
# Preprocessing images: 7350 /112120
# Up to now 7385 images processed： 89 pictures are not well shaped.
# No. of batches saved: 57
# The total number of images is 112120
# Preprocessing images: 7400 /112120
# Preprocessing images: 7450 /112120
# Preprocessing images: 7500 /112120
# Up to now 7514 images processed： 90 pictures are not well shaped.
# No. of batches saved: 58
# The total number of images is 112120
# Preprocessing images: 7550 /112120
# Preprocessing images: 7600 /112120
# Up to now 7642 images processed： 90 pictures are not well shaped.
# No. of batches saved: 59
# The total number of images is 112120
# Preprocessing images: 7650 /112120
# Preprocessing images: 7700 /112120
# Preprocessing images: 7750 /112120
# Up to now 7770 images processed： 90 pictures are not well shaped.
# No. of batches saved: 60
# The total number of images is 112120
# Preprocessing images: 7800 /112120
# Preprocessing images: 7850 /112120
# Preprocessing images: 7900 /112120
# Up to now 7900 images processed： 92 pictures are not well shaped.
# No. of batches saved: 61
# The total number of images is 112120
# Preprocessing images: 7950 /112120
# Preprocessing images: 8000 /112120
# Up to now 8032 images processed： 96 pictures are not well shaped.
# No. of batches saved: 62
# The total number of images is 112120
# Preprocessing images: 8050 /112120
# Preprocessing images: 8100 /112120
# Preprocessing images: 8150 /112120
# Up to now 8160 images processed： 96 pictures are not well shaped.
# No. of batches saved: 63
# The total number of images is 112120
# Preprocessing images: 8200 /112120
# Preprocessing images: 8250 /112120
# Up to now 8289 images processed： 97 pictures are not well shaped.
# No. of batches saved: 64
# The total number of images is 112120
# Preprocessing images: 8300 /112120
# Preprocessing images: 8350 /112120
# Preprocessing images: 8400 /112120
# Up to now 8420 images processed： 100 pictures are not well shaped.
# No. of batches saved: 65
# The total number of images is 112120
# Preprocessing images: 8450 /112120
# Preprocessing images: 8500 /112120
# Preprocessing images: 8550 /112120
# Up to now 8550 images processed： 102 pictures are not well shaped.
# No. of batches saved: 66
# The total number of images is 112120
# Preprocessing images: 8600 /112120
# Preprocessing images: 8650 /112120
# Up to now 8678 images processed： 102 pictures are not well shaped.
# No. of batches saved: 67
# The total number of images is 112120
# Preprocessing images: 8700 /112120
# Preprocessing images: 8750 /112120
# Preprocessing images: 8800 /112120
# Up to now 8808 images processed： 104 pictures are not well shaped.
# No. of batches saved: 68
# The total number of images is 112120
# Preprocessing images: 8850 /112120
# Preprocessing images: 8900 /112120
# Up to now 8936 images processed： 104 pictures are not well shaped.
# No. of batches saved: 69
# The total number of images is 112120
# Preprocessing images: 8950 /112120
# Preprocessing images: 9000 /112120
# Preprocessing images: 9050 /112120
# Up to now 9064 images processed： 104 pictures are not well shaped.
# No. of batches saved: 70
# The total number of images is 112120
# Preprocessing images: 9100 /112120
# Preprocessing images: 9150 /112120
# Up to now 9193 images processed： 105 pictures are not well shaped.
# No. of batches saved: 71
# The total number of images is 112120
# Preprocessing images: 9200 /112120
# Preprocessing images: 9250 /112120
# Preprocessing images: 9300 /112120
# Up to now 9322 images processed： 106 pictures are not well shaped.
# No. of batches saved: 72
# The total number of images is 112120
# Preprocessing images: 9350 /112120
# Preprocessing images: 9400 /112120
# Preprocessing images: 9450 /112120
# Up to now 9451 images processed： 107 pictures are not well shaped.
# No. of batches saved: 73
# The total number of images is 112120
# Preprocessing images: 9500 /112120
# Preprocessing images: 9550 /112120
# Up to now 9579 images processed： 107 pictures are not well shaped.
# No. of batches saved: 74
# The total number of images is 112120
# Preprocessing images: 9600 /112120
# Preprocessing images: 9650 /112120
# Preprocessing images: 9700 /112120
# Up to now 9708 images processed： 108 pictures are not well shaped.
# No. of batches saved: 75
# The total number of images is 112120
# Preprocessing images: 9750 /112120
# Preprocessing images: 9800 /112120
# Up to now 9837 images processed： 109 pictures are not well shaped.
# No. of batches saved: 76
# The total number of images is 112120
# Preprocessing images: 9850 /112120
# Preprocessing images: 9900 /112120
# Preprocessing images: 9950 /112120
# Up to now 9966 images processed： 110 pictures are not well shaped.
# No. of batches saved: 77
# The total number of images is 112120
# Preprocessing images: 10000 /112120
# Preprocessing images: 10050 /112120
# Up to now 10096 images processed： 112 pictures are not well shaped.
# No. of batches saved: 78
# The total number of images is 112120
# Preprocessing images: 10100 /112120
# Preprocessing images: 10150 /112120
# Preprocessing images: 10200 /112120
# Up to now 10226 images processed： 114 pictures are not well shaped.
# No. of batches saved: 79
# The total number of images is 112120
# Preprocessing images: 10250 /112120
# Preprocessing images: 10300 /112120
# Preprocessing images: 10350 /112120
# Up to now 10354 images processed： 114 pictures are not well shaped.
# No. of batches saved: 80
# The total number of images is 112120
# Preprocessing images: 10400 /112120
# Preprocessing images: 10450 /112120
# Up to now 10482 images processed： 114 pictures are not well shaped.
# No. of batches saved: 81
# The total number of images is 112120
# Preprocessing images: 10500 /112120
# Preprocessing images: 10550 /112120
# Preprocessing images: 10600 /112120
# Up to now 10611 images processed： 115 pictures are not well shaped.

# %% [markdown]
# ### Things to do:
#
# 1. Try to save the pictures as integer arrays...
#
# 2.
